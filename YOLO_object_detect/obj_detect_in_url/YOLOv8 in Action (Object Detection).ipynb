# %%
# Install ultralytics library
#!pip install ultralytics

# %%
# Import YOLO
from ultralytics import YOLO

# %%
# Load a pre-trained YOLOv8 model (nano version for speed)
model = YOLO('yolov8n.pt')

# %%
# Run detection on an image
results = model('https://ultralytics.com/images/bus.jpg')
# Out:
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 C:\Users\Ashwinbarath\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 90.6ms
# Speed: 2.1ms preprocess, 90.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 480)

# %%
# Show the results
results[0].show()

# %%
# Save results to folder
results[0].save('output/')
# Out:
# 'output/'
